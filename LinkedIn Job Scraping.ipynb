# %%
from selenium import webdriver
import time
import pandas as pd
import os

from selenium.webdriver.support.select import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as ec
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %%
url1 = 'https://www.linkedin.com/login'

# %%
mail = 'enter your linkedin email/username'
password = 'enter your linkedin password'

# %%
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)
driver.get(url1)
driver.implicitly_wait(10)

# %%
driver.find_element(By.XPATH,"//input[@type='text']").send_keys(mail)
driver.find_element(By.XPATH,"//input[@type='password']").send_keys(password)
driver.find_element(By.XPATH,"//button[@class='btn__primary--large from__button--floating']").click()

# %%
url2 = 'https://www.linkedin.com/jobs/search/?currentJobId=3970858637&keywords=analyst&location=Dhaka%2C%20Bangladesh&origin=JOBS_HOME_SEARCH_BUTTON&refresh=true'

# %%
driver.get(url2)

# %%
import pandas as pd

ljob_title = []
lcompany_name = []
ljob_location = []
lposted_on = []
ljob_desc = []
lnum_app = []

# %%
# jobs = driver.find_elements(By.XPATH, "//ul[@class='scaffold-layout__list-container']/li")

# for job in jobs:
#     driver.execute_script("arguments[0].scrollIntoView();", job)
#     time.sleep(1)
    
# links = driver.find_elements(By.XPATH,"//ul[@class='scaffold-layout__list-container']/li")
# for link in links:
#     link.click()
#     time.sleep(3)
#     job_title = driver.find_element(By.XPATH,"//h1[@class='t-24 t-bold inline']").text
#     #job_location = driver.find_element(By.XPATH,"//body/div[@class='application-outlet']/div[@class='authentication-outlet']/div[4]/div[1]/div[1]/main[1]/div[1]/div[2]/div[2]/div[1]/div[2]/div[1]/div[1]/div[1]/div[1]/div[1]/div[1]/div[1]/div[3]/div[1]/span[1]").text
#     company_name = driver.find_element(By.XPATH, "//div[@class='job-details-jobs-unified-top-card__company-name']").text
#     posted_on = driver.find_element(By.XPATH,"//span[@class='tvm__text tvm__text--low-emphasis'][3]").text
#     #job_desc = driver.find_element(By.XPATH, "//h2[@class='text-heading-large']//div[@class='mt4']").text
#     num_app = driver.find_element(By.XPATH,"//span[@class='tvm__text tvm__text--low-emphasis'][3]").text
    
#     ljob_title.append(job_title)
#     lcompany_name.append(company_name)
#     ljob_location.append(job_location)
#     lposted_on.append(posted_on)
#     #ljob_desc.append(job_desc)
#     lnum_app.append(num_app)

# %%
jobs = driver.find_elements(By.XPATH, "//ul[@class='scaffold-layout__list-container']/li")

for job in jobs:
    driver.execute_script("arguments[0].scrollIntoView();", job)
    time.sleep(1)
    
links = driver.find_elements(By.XPATH,"//ul[@class='scaffold-layout__list-container']/li")
for link in links:
    link.click()
    time.sleep(3)
    job_title = driver.find_element(By.XPATH,"//h1[@class='t-24 t-bold inline']").text
    job_location = driver.find_element(By.XPATH,"//div[@class='artdeco-entity-lockup__caption ember-view']").text
    company_name = driver.find_element(By.XPATH, "//div[@class='job-details-jobs-unified-top-card__company-name']").text
    posted_on = driver.find_element(By.XPATH,"//div[1]//div[1]//main[1]//div[1]//div[2]//div[2]//div[1]//div[2]//div[1]//div[1]//div[1]//div[1]//div[1]//div[1]//div[1]//div[3]//div[1]//span[3]").text
    #job_desc = driver.find_element(By.XPATH, "//h2[@class='text-heading-large']//div[@class='mt4']").text
    num_app = driver.find_element(By.XPATH,"//div[1]//div[1]//main[1]//div[1]//div[2]//div[2]//div[1]//div[2]//div[1]//div[1]//div[1]//div[1]//div[1]//div[1]//div[1]//div[3]//div[1]//span[5]").text
    
    ljob_title.append(job_title)
    lcompany_name.append(company_name)
    ljob_location.append(job_location)
    lposted_on.append(posted_on)
    #ljob_desc.append(job_desc)
    lnum_app.append(num_app)

# %%
print("Job Title:", len(ljob_title))
print("Company Name:", len(lcompany_name))
print("Job Location:", len(ljob_location))
print("Posted On:", len(lposted_on))
print("Number of Applicants:", len(lnum_app))
# Out:
# Job Title: 25
# Company Name: 25
# Job Location: 25
# Posted On: 25
# Number of Applicants: 25

# %%
print(ljob_location)
# Out:
# ['Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)', 'Dhaka, Dhaka, Bangladesh (On-site)']

# %%
data = {
    "Job Title": ljob_title,
    "Company Name": lcompany_name,
    "Job Location": "Dhaka, Bangladesh",
    "Posted On": lposted_on,
#     "Job Description": ljob_desc,
    "Number of Applicants ": lnum_app
}

newdf = pd.DataFrame(data)

# %%
newdf
# Out:
#                                             Job Title  \
# 0   Data Scientist- (For Gildan-G.A.B. Limited) - ...
# 1                       Oracle Database Administrator
# 2                                      Data Scientist
# 3                                       Data Engineer
# 4   Executive/Sr. Executive - ICT (ERP) - For A Re...
# 5   Executive/ Sr. Executive - Performance Managem...
# 6                                             Analyst
# 7                             Immunization Consultant
# 8                               AI Software QA Tester
# 9      Software Engineer for AI Training Data (Swift)
# 10  Network Engineer-IT - For Best Tycoon (BD) Ent...
# 11                                       Data Analyst
# 12       Analyst, Logistics(Freight Pay Origin-Panyu)
# 13                          Machine Learning Engineer
# 14    Software Engineer for AI Training Data (Python)
# 15      Associate Systems Engineer / Systems Engineer
# ...

# %%
newdf.to_csv("LinkedIn_Jobs.csv", index = True)
